# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
ax = plt.subplot()
# plt.show()
plt.plot([1,2,3,4],[1,4,2,3])
# plt.show()
fig = plt.figure()
# plt.show
axs = plt.subplots(2,2)
plt.show()

# %%
axs =plt.subplots(2,2)
plt.show()

# %%
Dict = {1:'Greeks',2:"For",3:'Greek'}
print(Dict)
list1 =[1,2,3,4,5]
print(list1)
tuple1 =(1,2,3,4)
print(tuple1)
# Out:
# {1: 'Greeks', 2: 'For', 3: 'Greek'}
# [1, 2, 3, 4, 5]
# (1, 2, 3, 4)

# %%
import numpy as np
x = np.linspace(0,2,100)
ax = plt.subplots()
plt.plot(x,x,label='line')
plt.plot(x,x**2,label='quadriatic')
plt.plot(x,x**3,label='cubic')
plt.xlabel('x lable')
plt.ylabel('y lable')
plt.title('Simple Plot')
plt.title('Simple Plot')
plt.legend()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
x = torch.rand(5, 3)
a = pd.Series([1,2,3])
print(x)
print(a)
x = np.linspace(2,100)
y = np.linspace(0,2,100)
ax = plt.subplot()
plt.plot(x,x,label='linear')
plt.plot(x,x**2,label='Quadric')
plt.plot(x,x**3,label='Cubic')
plt.title(label='Simple Plot')
plt.plot(y,y,label='Linear')

plt.legend()
# Out:
# tensor([[0.1837, 0.9320, 0.8030],
#         [0.0977, 0.6822, 0.6643],
#         [0.7418, 0.4110, 0.4798],
#         [0.8681, 0.0851, 0.3042],
#         [0.9246, 0.1633, 0.8997]])
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.7261, 0.4763, 0.2059],
#         [0.2032, 0.6175, 0.0499],
#         [0.0700, 0.4636, 0.7950],
#         [0.1368, 0.0892, 0.0983],
#         [0.2731, 0.9445, 0.7800]])
