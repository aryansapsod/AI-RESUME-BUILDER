# %%
# Parameterised Function:
def function(p1):
    """Tnis is Document String"""
    print("Inside function")
    print("Value of p1 ={p1} ")

function(20)
# Out:
# Inside function
# Value of p1 ={p1}

# %%
num1 = 10
print(num1)

if num1 == 10:
    print("Inner block")
    print(num1)
if num1 <= 10:
    print("inner block")
    print(num1)
if num1 >= 10:
    print("inner block")
    print(num1)
# Out:
# 10
# Inner block
# 10
# inner block
# 10
# inner block
# 10

# %%
# Even - Odd

num1 =int(input("Enter a number= "))

if num1%2 == 0:
    print("Even number")
else:
    print("Odd Number")
# Out:
# Even number

# %%
def function1():
    print('Instide a Function')

function1()
# Out:
# Instide a Function

# %%
#Parameterless Functions
num1 =int(input('Enter a Number= '))
def f():
    print(f"Num1 ={num1}")

f()
# Out:
# Num1 =4

# %%
num1 = 20  # --> Arguments
def function1():
    print("inside function1")
    print(f"num1 ={num1}")

function1()
# Out:
# inside function1
# num1 =20

# %%
def function4():
    print("Inside function 4")
    print()
function4()
# Out:
# Inside function 4

# %%
def function5(p1,p2):
    print("inside function5")
    print(f"p1 ={p1},type of p1 ={type(p1)}")
    print(f"p1 ={p2},type of p2 ={type(p2)}")
function5(10,20)
# Out:
# inside function5
# p1 =10,type of p1 =<class 'int'>
# p1 =20,type of p2 =<class 'int'>

# %%
def function6(p1,p2):
    print("Inside Function6")
    print(f"p1 ={p1},type of p1 ={type(p1)}")
    print(f"p2 ={p2},type of p2 ={type(p2)}")
function6(10.23,12.33)
# Out:
# Inside Function6
# p1 =10.23,type of p1 =<class 'float'>
# p2 =12.33,type of p2 =<class 'float'>

# %%
def function6(p1,p2):
    print("Inside Function6")
    print(f"p1 ={p1},type of p1 ={type(p1)}")
    print(f"p2 ={p2},type of p2 ={type(p2)}")
function6('b',"b")
# Out:
# Inside Function6
# p1 =b,type of p1 =<class 'str'>
# p2 =b,type of p2 =<class 'str'>

# %%
def function6(p1,p2):
    print("Inside Function6")
    print(f"p1 ={p1},type of p1 ={type(p1)}")
    print(f"p2 ={p2},type of p2 ={type(p2)}")
function6(10.6,6)
# Out:
# Inside Function6
# p1 =10.6,type of p1 =<class 'float'>
# p2 =6,type of p2 =<class 'int'>

# %%
num1=10
num2=20
def function1():
    print("Inside parameterless function")
    print(num1+num2)

function1()
# Out:
# Inside parameterless function
# 30

# %%
# Empty function

def function2():
    pass
function2()

# %%
#non returning function

def add(p1,p2):
    print("Non returning function")
    result = p1 +p2
    print(f"Result ={result}")

add(10,20)
# Out:
# Non returning function
# Result =30

# %%
# Returning function
def sun(p1,p2):
    print("Inside Returning function")
    result =p1+p2
    return result
addtion = sun(10,20)
print(addtion)
# Out:
# Inside Returning function
# 30

# %%
# default value of parameter
def sun(p1,p2,p3=0):
    result=p1+p2+p3

    print(f"result ={result}")

sun(10,20)
# Out:
# result =30
